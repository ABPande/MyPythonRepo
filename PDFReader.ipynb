# %%
import PyPDF2

# %%
myfile = open("C:\\ABHIJIT PANDE V6.pdf", mode = "rb")

# %%
pdf_reader = PyPDF2.PdfFileReader(myfile)

# %%
pdf_reader.numPages
# Out:
# 2

# %%
page_one = pdf_reader.getPage(0)

# %%
page_one_text = page_one.extractText()

# %%
print(page_one_text)
# Out:
# ABHIJIT PANDE
#
# CLIENT AND MARKET RESEARCH, TECHNOLOGY ARCHITECTURE,
# INNOVATION
# &
#
# BUSINESS/
# PROCESS TRANSFORMATION
#
#
# Abhijit Pande
#
# Abhijit.a.pande@gmail.com
#
# 91
# -
# 9922910722
#
# Pune
#
#
# SUMMARY:
#
# A recognized specialist with
# deep expertise in
# Technology,
# Business Transformation and Innovation
# . Over a
# decade of experience in Financial services and
# four
#
# years in Public administration.
#
# Currently tasked with
# transformation of Sales and Deal making at Accenture
#
# SKILLS
# :
#
# Industry
#
#
#
# Insurance
#
#
#
# Banking
#
#
#
# Public
# administration
#
#
#
# Telecom
#
# Tech
#
#
#
# AI (Machine Learning, Deep
# Learning,
# Computer Vision
# ,
# NLP
# )
#
#
#
# Automation (ARP)
#
#
#
# DevOps
#
# (Jenkins)
#
#
#
# Databases (MS, DB2, ORA)
#
#
#
# Application Development
# (Java/
# .NET
# )
#
# Process
#
#
#
# Proposal development
#
#
#
# Incident/Service
# Management
#
# (JIRA, Remedy,
# ServiceNow)
#
#
#
# ...

# %%
myfile.close()
myfile = None

# %%
myfile = open("C:\\ABHIJIT PANDE V6.pdf", mode = "rb")
pdf_reader = PyPDF2.PdfFileReader(myfile)
pdf_reader.numPages
# Out:
# 2

# %%
page1 = pdf_reader.getPage(0)
page2 = pdf_reader.getPage(1)
page1_text = page1.extractText()
page2_text = page2.extractText()

# %%
print(page1_text)
print(page2_text)
# Out:
# ABHIJIT PANDE
#
# CLIENT AND MARKET RESEARCH, TECHNOLOGY ARCHITECTURE,
# INNOVATION
# &
#
# BUSINESS/
# PROCESS TRANSFORMATION
#
#
# Abhijit Pande
#
# Abhijit.a.pande@gmail.com
#
# 91
# -
# 9922910722
#
# Pune
#
#
# SUMMARY:
#
# A recognized specialist with
# deep expertise in
# Technology,
# Business Transformation and Innovation
# . Over a
# decade of experience in Financial services and
# four
#
# years in Public administration.
#
# Currently tasked with
# transformation of Sales and Deal making at Accenture
#
# SKILLS
# :
#
# Industry
#
#
#
# Insurance
#
#
#
# Banking
#
#
#
# Public
# administration
#
#
#
# Telecom
#
# Tech
#
#
#
# AI (Machine Learning, Deep
# Learning,
# Computer Vision
# ,
# NLP
# )
#
#
#
# Automation (ARP)
#
#
#
# DevOps
#
# (Jenkins)
#
#
#
# Databases (MS, DB2, ORA)
#
#
#
# Application Development
# (Java/
# .NET
# )
#
# Process
#
#
#
# Proposal development
#
#
#
# Incident/Service
# Management
#
# (JIRA, Remedy,
# ServiceNow)
#
#
#
# ...

# %%
output = open("C:\\Users\\abhijit.a.pande\\Desktop\\Performance\\CVs\\AbhijitPandeV7.pdf","wb")
pdf_writer = PyPDF2.PdfFileWriter()
pdf_writer.addPage(page1)
pdf_writer.addPage(page2)
pdf_writer.write(output)
output.close()
