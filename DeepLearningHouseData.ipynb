# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\abhijit.a.pande\\Machine Learning\\datasets\\kc_house_data.csv")

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df["yr_built"] = df["yr_built"] - 1900
df["yr_built"].min()
# Out:
# 0

# %%
def renovate(years):
    if years>0:
        years = years - 1900
    return years
df['yr_renovated'] = df['yr_renovated'].apply(renovate)

# %%
df.isnull().sum().head()
# Out:
# id           0
# date         0
# price        0
# bedrooms     0
# bathrooms    0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
plt.figure(figsize = (20,20))
sb.distplot(df["price"])

# %%
sb.countplot(df["bedrooms"])

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.131495
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize = (10,6))
sb.scatterplot(x=  "price", y = "sqft_living", data = df)

# %%
sb.boxplot(x = "bedrooms", y = "price", data = df)

# %%
sb.scatterplot(x = "price", y = "long", data = df)

# %%
sb.scatterplot(x = "price", y = "lat", data = df)

# %%
sb.scatterplot(x = "long", y = "lat", data = df, hue = "price" )

# %%
df = df.sort_values("price", ascending = False).iloc[216:]

# %%
plt.figure(figsize = (10,10))
sb.distplot(df["price"])

# %%
plt.figure(figsize = (10,10))
sb.scatterplot(x ="long", y = "lat", data = modified_df, hue = "price", palette = "RdYlGn",alpha = 0.4, edgecolor = None)

# %%
sb.boxplot(x = "waterfront", y = "price", data = df)

# %%
df.head()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 6329       8510     2.0           0     1  ...     10        3610
# 12271     23373     3.0           0     1  ...     11        5050
# 9166      12566     1.0           1     4  ...      8        1940
# 12565     31353     2.0           0     0  ...     12        4430
# 1150       7898     1.0           1     4  ...      8        1560
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df = df.drop("id", axis =1)

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["year"] = df["date"].apply(lambda date: date.year)
df["month"] = df["date"].apply(lambda date: date.month)

# %%
df.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6329  2014-06-02  1970000.0         4       3.50         4370      8510
# 12271 2014-10-15  1960000.0         5       4.50         6200     23373
# 9166  2015-02-13  1960000.0         3       1.75         3330     12566
# 12565 2015-04-22  1960000.0         4       4.00         4430     31353
# 1150  2015-04-21  1960000.0         4       2.75         3120      7898
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 6329      2.0           0     1          3  ...            760       103
# 12271     3.0           0     1          4  ...           1150        88
# 9166      1.0           1     4          4  ...           1390        60
# 12565     2.0           0     0          3  ...              0        98
# 1150      1.0           1     4          4  ...           1560        63
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
sb.boxplot(x = "month", y = "price", data =df)

# %%
df['yr_built'] = 9999 - df['yr_built']
df.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6329  2014-06-02  1970000.0         4       3.50         4370      8510
# 12271 2014-10-15  1960000.0         5       4.50         6200     23373
# 9166  2015-02-13  1960000.0         3       1.75         3330     12566
# 12565 2015-04-22  1960000.0         4       4.00         4430     31353
# 1150  2015-04-21  1960000.0         4       2.75         3120      7898
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 6329      2.0           0     1          3  ...            760      9896
# 12271     3.0           0     1          4  ...           1150      9911
# 9166      1.0           1     4          4  ...           1390      9939
# 12565     2.0           0     0          3  ...              0      9901
# 1150      1.0           1     4          4  ...           1560      9936
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
sb.boxplot(x = "condition", y = "price", data = df[df["price"]<1250000])

# %%
df["zipcode"]
# Out:
# 6329     98004
# 12271    98040
# 9166     98040
# 12565    98005
# 1150     98034
#          ...
# 2139     98168
# 8267     98146
# 16184    98168
# 465      98014
# 15279    98168
# Name: zipcode, Length: 21381, dtype: int64

# %%
x  = df.drop("zipcode", axis = 1)
x = x.drop("date", axis = 1)
x = x.drop("price", axis = 1)
x = x.drop("lat", axis = 1)
x = x.drop("long", axis = 1)
x = x.drop("month", axis = 1)

# %%
x = x[:].values

# %%
x
# Out:
# array([[4.0000e+00, 3.5000e+00, 4.3700e+03, ..., 2.9600e+03, 1.0347e+04,
#         2.0140e+03],
#        [5.0000e+00, 4.5000e+00, 6.2000e+03, ..., 3.7000e+03, 1.4486e+04,
#         2.0140e+03],
#        [3.0000e+00, 1.7500e+00, 3.3300e+03, ..., 3.7300e+03, 1.6560e+04,
#         2.0150e+03],
#        ...,
#        [2.0000e+00, 1.0000e+00, 7.3000e+02, ..., 8.6000e+02, 9.0000e+03,
#         2.0150e+03],
#        [1.0000e+00, 7.5000e-01, 4.3000e+02, ..., 1.2000e+03, 7.5000e+03,
#         2.0140e+03],
#        [2.0000e+00, 1.0000e+00, 7.8000e+02, ..., 1.7000e+03, 1.0387e+04,
#         2.0140e+03]])

# %%
y = df["price"].values

# %%
y
# Out:
# array([1970000., 1960000., 1960000., ...,   81000.,   80000.,   78000.])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler()

# %%
mm.fit(x_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
x_train = mm.transform(x_train)

# %%
x_test = mm.transform(x_test)

# %%
x_test
# Out:
# array([[6.25000000e-02, 2.85714286e-01, 1.90476190e-01, ...,
#         2.38273921e-01, 3.84699770e-03, 0.00000000e+00],
#        [9.37500000e-02, 3.21428571e-01, 2.69387755e-01, ...,
#         3.18949343e-01, 9.35386750e-03, 0.00000000e+00],
#        [6.25000000e-02, 1.78571429e-01, 1.97278912e-01, ...,
#         5.47842402e-01, 1.17201904e-02, 0.00000000e+00],
#        ...,
#        [3.12500000e-02, 2.50000000e-01, 4.78911565e-01, ...,
#         3.97748593e-01, 5.20705899e-03, 0.00000000e+00],
#        [6.25000000e-02, 3.57142857e-02, 7.34693878e-02, ...,
#         1.31707317e-01, 6.20918524e-02, 0.00000000e+00],
#        [3.12500000e-02, 2.50000000e-01, 1.04761905e-01, ...,
#         1.29455910e-01, 1.11423941e-04, 1.00000000e+00]])

# %%
x
# Out:
# array([[4.0000e+00, 3.5000e+00, 4.3700e+03, ..., 2.9600e+03, 1.0347e+04,
#         2.0140e+03],
#        [5.0000e+00, 4.5000e+00, 6.2000e+03, ..., 3.7000e+03, 1.4486e+04,
#         2.0140e+03],
#        [3.0000e+00, 1.7500e+00, 3.3300e+03, ..., 3.7300e+03, 1.6560e+04,
#         2.0150e+03],
#        ...,
#        [2.0000e+00, 1.0000e+00, 7.3000e+02, ..., 8.6000e+02, 9.0000e+03,
#         2.0150e+03],
#        [1.0000e+00, 7.5000e-01, 4.3000e+02, ..., 1.2000e+03, 7.5000e+03,
#         2.0140e+03],
#        [2.0000e+00, 1.0000e+00, 7.8000e+02, ..., 1.7000e+03, 1.0387e+04,
#         2.0140e+03]])

# %%
model = Sequential()
model.add(Dense(18, activation = "relu"))
model.add(Dense(18, activation = "relu"))
model.add(Dense(18, activation = "relu"))

model.add(Dense(1))

model.compile(optimizer="adam", loss = "mae")

# %%
model.fit(x = x_train, y = y_train, epochs = 100, verbose = 2, validation_data=(x_test,y_test))
# Out:
# Train on 14966 samples, validate on 6415 samples
# Epoch 1/100
# 14966/14966 - 3s - loss: 518412.4503 - val_loss: 516660.9599
# Epoch 2/100
# 14966/14966 - 1s - loss: 513726.7459 - val_loss: 505930.0147
# Epoch 3/100
# 14966/14966 - 1s - loss: 490139.8375 - val_loss: 465117.5408
# Epoch 4/100
# 14966/14966 - 1s - loss: 421412.1636 - val_loss: 362210.4239
# Epoch 5/100
# 14966/14966 - 1s - loss: 279468.8713 - val_loss: 195382.1971
# Epoch 6/100
# 14966/14966 - 1s - loss: 171520.6799 - val_loss: 160783.6809
# Epoch 7/100
# 14966/14966 - 1s - loss: 162328.6244 - val_loss: 157204.3798
# Epoch 8/100
# 14966/14966 - 1s - loss: 158873.1440 - val_loss: 154083.0067
# Epoch 9/100
# 14966/14966 - 1s - loss: 155851.1799 - val_loss: 151249.1449
# Epoch 10/100
# 14966/14966 - 1s - loss: 153207.9645 - val_loss: 148886.5159
# Epoch 11/100
# 14966/14966 - 1s - loss: 150942.8028 - val_loss: 146865.4495
# Epoch 12/100
# 14966/14966 - 1s - loss: 149038.2937 - val_loss: 144939.9802
# Epoch 13/100
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
predictions = model.predict(x_test)

# %%
predictions.reshape(6415,1)
# Out:
# array([[451585.47],
#        [445610.06],
#        [683930.9 ],
#        ...,
#        [982838.56],
#        [531645.5 ],
#        [251034.72]], dtype=float32)

# %%
pred_df = pd.DataFrame(pd.Series(predictions.reshape(6415,)))
y_df = pd.DataFrame(pd.Series(y_test.reshape(6415,)))
outcome = pd.concat([pred_df, y_df],axis = 1)

# %%
outcome.columns = ["Predicted", "Real"]

# %%
outcome.head()
# Out:
#       Predicted      Real
# 0  451585.46875  459000.0
# 1  445610.06250  405000.0
# 2  683930.87500  550000.0
# 3  732207.06250  448000.0
# 4  248914.46875  336900.0

# %%
mean_absolute_error(outcome["Real"], outcome["Predicted"])
# Out:
# 119400.60229667487

# %%
mean_squared_error(outcome["Real"], outcome["Predicted"])
# Out:
# 28920923401.953392

# %%
plt.scatter(outcome["Real"],outcome["Predicted"])
plt.tight_layout()

# %%
pd.DataFrame(model.history.history).plot()
