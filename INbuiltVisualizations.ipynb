# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df1 = pd.read_csv('C:\\Users\\abhijit.a.pande\\machine learning\\Py_DS_ML_BC\\07-Pandas-Built-in-Data-Viz\\df1', index_col = 0)
df2 = pd.read_csv('C:\\Users\\abhijit.a.pande\\machine learning\\Py_DS_ML_BC\\07-Pandas-Built-in-Data-Viz\\df2', index_col = 0)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2
# Out:
#                  b         c         d
# a
# 0.039762  0.218517  0.103423  0.957904
# 0.937288  0.041567  0.899125  0.977680
# 0.780504  0.008948  0.557808  0.797510
# 0.672717  0.247870  0.264071  0.444358
# 0.053829  0.520124  0.552264  0.190008
# 0.286043  0.593465  0.907307  0.637898
# 0.430436  0.166230  0.469383  0.497701
# 0.312296  0.502823  0.806609  0.850519
# 0.187765  0.997075  0.895955  0.530390
# 0.908162  0.232726  0.414138  0.432007

# %%
df1['A'].hist(bins = 30)

# %%
df1['A'].plot (kind = 'hist', bins = 10)

# %%
df2.plot.area(alpha = 0.4)

# %%
df2.plot.bar(stacked = True)

# %%
df1['A'].plot.hist(bins = 15)

# %%
df1.to_csv("DF1.csv")
df1 = pd.read_csv("DF1.csv")

# %%
df1
# Out:
#      Unnamed: 0         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
df1.columns = ['Index','A','B','C','D']

# %%
df1
# Out:
#           Index         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
df1.plot.line(x = 'Index', y = 'B', figsize = (12,3),lw = 1)

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm',s= df1['C']*100)
# Out:
# C:\Users\abhijit.a.pande\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns = ['A','B'])
df.plot.hexbin(x = 'A', y = 'B', gridsize = 25, cmap = 'magma')

# %%
df2.columns = ['a','b','c']

# %%
df2.plot.density()
