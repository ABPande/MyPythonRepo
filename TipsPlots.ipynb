# %%
import numpy as np
import seaborn as sb
import pandas as pd
# %matplotlib inline

tips = sb.load_dataset('tips')
sb.barplot(x = 'sex', y = 'total_bill', data = tips, estimator = np.std )

# %%
sb.countplot(x = 'sex', data = tips)

# %%
sb.boxplot (x = 'day', y = 'total_bill', data = tips, hue = 'smoker')

# %%
sb.violinplot(x = 'day', y = 'total_bill', data = tips, split = True, hue = 'sex')
sb.`

# %%
sb.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True)

# %%
sb.swarmplot (x = 'day', y = 'total_bill',data = tips)

# %%
sb.catplot (x = 'day', y = 'tip', data = tips, kind = 'bar')

# %%
flights = sb.load_dataset('flights')

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
flights.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sb.heatmap(tips.corr(), annot = True)

# %%
fp = flights.pivot_table (values = "passengers", index = "month", columns = "year" )
sb.heatmap (fp, cmap = 'magma', linecolor = 'white', linewidths = 2)

# %%
sb.clustermap(fp)

# %%
iris = sb.load_dataset('iris')

# %%
g = sb.PairGrid(iris)
import matplotlib.pyplot as plt
g.map(plt.scatter)
g.map_diag(sb.distplot)
g.map_upper(plt.scatter)
g.map_lower(sb.kdeplot)

# %%
g = sb.FacetGrid(data = tips, col = 'time', row = 'smoker', hue = 'sex')
g.map(plt.scatter,'total_bill','tip')
